# %%
options(stringsAsFactors=F)
suppressMessages(library("data.table"))
suppressMessages(library("dplyr"))

# %%
genelist <- as.data.frame(fread("../../post-GWAS-pipeline//GeneList.txt"))

# %%
head(genelist)
# Out:
#   CHR POS       GENE
# 1 10   60936348 PHYHIPL
# 2 10   72575704 SGPL1
# 3 10  135043778 UTF1
# 4 11   66493871 SPTBN2
# 5  1  207100379 FCMR
# 6  1   28286504 XKR8

# %%
?split
# Out:
# split                package:data.table                R Documentation
#
# t
#
# n:
#
#      Split method for data.table. Faster and more flexible. Be aware
#      that processing list of data.tables will be generally much slower
#      than manipulation in single data.table by group using ‘by’
#      argument, read more on ‘data.table’.
#
# e:
#
#      ## S3 method for class 'data.table'
#      split(x, f, drop = FALSE,
#            by, sorted = FALSE, keep.by = TRUE, flatten = TRUE,
#            ..., verbose = getOption("datatable.verbose"))
#
# s:
#
#        x: data.table
#
#        f: factor or list of factors. Same as ‘split.data.frame’. Use
#           ‘by’ argument instead, this is just for consistency with
#           data.frame method.
#
#     drop: logical. Default ‘FALSE’ will not drop empty list elements
#           caused by factor levels not referred by that factors. Works
#           also with new arguments of split data.table method.
#
# ...

# %%
output_list <- split(genelist, by=c("GENE"))
# Out:
# Error in deparse(...): unused argument (by = c("GENE"))
# Traceback:
#
# 1. split(genelist, by = c("GENE"))
# 2. split.data.frame(genelist, by = c("GENE"))
# 3. lapply(split(x = seq_len(nrow(x)), f = f, drop = drop, ...),
#  .     function(ind) x[ind, , drop = FALSE])
# 4. split(x = seq_len(nrow(x)), f = f, drop = drop, ...)
# 5. split.default(x = seq_len(nrow(x)), f = f, drop = drop, ...)
# 6. .NotYetUsed(deparse(...), error = FALSE)
# 7. gettextf("argument '%s' is not used (yet)", arg)
# 8. sprintf(gettext(fmt, domain = domain), ...)
