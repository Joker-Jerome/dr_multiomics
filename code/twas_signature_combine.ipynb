# %%
# add signatures

# %%
ln <- load("../../exp_res_ks_20191002.RData")

# %%
ln
# Out:
#  [1] "up_res_cc"         "up_res_pair_ez"    "down_res_cc"
#  [4] "down_res_pair_ez"  "up_signature_df"   "down_signature_df"
#  [7] "gene_rank_bing"    "compound_name"     "ks_score_df_cc"
# [10] "ks_score_df_pair"  "ks_score_df"

# %%
ln2 <- load("signature_list_twas_significant.RData")

# %%
head(up_signature_df)
# Out:
#   gene_id log2FC    Paired_TTest.x       P_adjusted.x entrezgene_id
# 1 IGFBP2  2.0973080 0.000202895105445194 0.012531722    3485
# 2 CMYA5   1.1595890 0.000351286063494227 0.015516680  202333
# 3 CA14    1.1577054 7.21898619031281e-05 0.008572901   23632
# 4 PPARA   0.9425177 3.8419130807681e-06  0.003508627    5465
# 5 CYP1A2  0.8565970 0.00102640671975578  0.026312026    1544
# 6 CDH23   0.8272671 7.71817164972887e-05 0.008742475   64072
#   ensembl_gene_id nash_1           nash_3           nash_5
# 1 ENSG00000115457 5.52600986116163 5.60623844775563 5.80123838936584
# 2 ENSG00000164309 5.10754545068052 4.52639783134358 5.06078860316949
# 3 ENSG00000118298 3.92695884103164 4.52667728148627 3.31228804446142
# 4 ENSG00000186951 7.09040716835301 7.94337760121244 7.06933213381294
# 5 ENSG00000140505 9.34437946338902 10.8478859370914 11.040719491202
# 6 ENSG00000107736 5.23963135189243 6.22435109678499 5.37161154805623
#   nash_6           ⋯ nonash_11        nonash_13        nonash_14
# 1 4.70580320806404 ⋯ 7.60762971901251 8.21710655454929 6.05645424467979
# 2 4.70682661957452 ⋯ 5.44503180669064 6.02702125102626 4.41449391819054
# 3 3.7611840986548  ⋯ 5.80102330076718 5.28823434108233 3.79072847009234
# 4 7.13154404430531 ⋯ 7.8350016561528  8.12317442534445 7.90121126226443
# 5 10.1625169249533 ⋯ 10.9719082267521 11.5007525062132 11.0083938173085
# 6 5.10531271851035 ⋯ 5.99937447328316 5.50561453595297 5.26636501596013
#   nonash_15        nonash_16        nonash_19        nonash_20
# 1 7.16480158201681 6.88515902007004 5.90900552371629 5.92910472620911
# 2 5.51407806636564 5.69491675835204 5.4191293368975  5.32986323229981
# 3 4.65248678502784 4.98535622245193 4.64702533395229 4.38276310543229
# 4 8.23448266748219 7.70176370316113 7.82085770678669 7.71299357059367
# 5 10.5601374150956 11.1931455636744 10.9987028630248 10.6536886036463
# 6 6.00836272358323 6.1225297657928  5.52887612781896 5.65554151422607
#   logFC             Paired_TTest.y       P_adjusted.y
# 1 1.45374314504699  0.000202895105445194 0.0125317222900259
# 2 0.803765816041033 0.000351286063494227 0.0155166800549362
# 3 0.802460236526014 7.21898619031281e-05 0.0085729014070367
# 4 0.653303496229666 3.8419130807681e-06  0.00350862712101147
# 5 0.593747788836952 0.00102640671975578  0.0263120262966165
# 6 0.573417879203735 7.71817164972887e-05 0.00874247473998747

# %%
signature_list_twas_significant
# Out:
# $BMI_GIANT_2015
#               gene    zscore   effect_size       pvalue   pvalue_adj
# 1          C1QTNF4 -8.558122 -3.442158e+01 1.147205e-17 8.700403e-14
# 273        EFCAB4A -3.200378 -1.269940e-01 1.372472e-03 4.892412e-02
# 274          ANKK1 -3.391472 -7.307320e-01 6.951825e-04 4.927350e-02
#             tissue
# 1            Liver
# 2            Liver
# 3            Liver
# 4   Liver_STARNET1
# 5   Liver_STARNET1
# 6   Liver_STARNET1
# 7   Liver_STARNET1
# 8            Liver
# 9   Liver_STARNET1
# 10  Liver_STARNET1
# 11           Liver
# 12           Liver
# 13           Liver
# 14           Liver
# 15           Liver
# 16           Liver
# 17           Liver
# 18  Liver_STARNET1
# 19           Liver
# 20  Liver_STARNET1
# 21           Liver
# 22           Liver
# 23           Liver
# 24           Liver
# 25           Liver
# 26           Liver
# 27  Liver_STARNET1
# 28  Liver_STARNET1
# 29           Liver
# 30  Liver_STARNET1
# 31           Liver
# 32  Liver_STARNET1
# 33           Liver
# 34           Liver
# 35  Liver_STARNET1
# 36  Liver_STARNET1
# 37           Liver
# 38           Liver
# 39  Liver_STARNET1
# 40  Liver_STARNET1
# 41  Liver_STARNET1
# 42  Liver_STARNET1
# 43  Liver_STARNET1
# 44           Liver
# 45           Liver
# 46  Liver_STARNET1
# 47  Liver_STARNET1
# 48           Liver
# 49  Liver_STARNET1
# 50           Liver
# 51           Liver
# 52           Liver
# 53           Liver
# 54           Liver
# 55           Liver
# 56  Liver_STARNET1
# 57  Liver_STARNET1
# 58  Liver_STARNET1
# 59  Liver_STARNET1
# 60           Liver
# 61  Liver_STARNET1
# 62  Liver_STARNET1
# 63           Liver
# 64  Liver_STARNET1
# 65  Liver_STARNET1
# 66  Liver_STARNET1
# 67  Liver_STARNET1
# 68           Liver
# 69           Liver
# 70           Liver
# 71           Liver
# 72  Liver_STARNET1
# 73           Liver
# 74  Liver_STARNET1
# 75           Liver
# 76  Liver_STARNET1
# 77  Liver_STARNET1
# 78  Liver_STARNET1
# 79  Liver_STARNET1
# 80  Liver_STARNET1
# 81  Liver_STARNET1
# 82           Liver
# 83           Liver
# 84           Liver
# 85  Liver_STARNET1
# 86  Liver_STARNET1
# 87  Liver_STARNET1
# 88           Liver
# 89           Liver
# 90           Liver
# 91           Liver
# 92           Liver
# 93  Liver_STARNET1
# 94  Liver_STARNET1
# 95  Liver_STARNET1
# 96           Liver
# 97  Liver_STARNET1
# 98           Liver
# 99           Liver
# 100          Liver
# 101 Liver_STARNET1
# 102 Liver_STARNET1
# 103 Liver_STARNET1
# 104 Liver_STARNET1
# 105 Liver_STARNET1
# 106 Liver_STARNET1
# 107 Liver_STARNET1
# 108 Liver_STARNET1
# 109 Liver_STARNET1
# 110          Liver
# 111 Liver_STARNET1
# 112 Liver_STARNET1
# 113          Liver
# 114          Liver
# 115          Liver
# 116 Liver_STARNET1
# 117 Liver_STARNET1
# 118 Liver_STARNET1
# 119 Liver_STARNET1
# 120 Liver_STARNET1
# 121          Liver
# 122          Liver
# 123 Liver_STARNET1
# 124 Liver_STARNET1
# 125          Liver
# 126 Liver_STARNET1
# 127 Liver_STARNET1
# 128          Liver
# 129          Liver
# 130          Liver
# 131          Liver
# 132          Liver
# 258 Liver_STARNET1
# 259 Liver_STARNET1
# 260 Liver_STARNET1
# 261 Liver_STARNET1
# 262 Liver_STARNET1
# 263 Liver_STARNET1
# 264          Liver
# 265 Liver_STARNET1
# 266          Liver
# 267          Liver
# 268          Liver
# 269          Liver
# 270          Liver
# 271 Liver_STARNET1
# 272 Liver_STARNET1
# 273 Liver_STARNET1
# 274          Liver
#
# $CAD
#          gene    zscore   effect_size       pvalue   pvalue_adj         tissue
# 1      CELSR2 -6.080397 -4.906468e-01 1.198854e-09 3.889522e-06 Liver_STARNET1
# 2       PSRC1 -6.039615 -4.659235e-01 1.544822e-09 3.889522e-06 Liver_STARNET1
# 3       SORT1 -6.001078 -3.927058e-01 1.960115e-09 3.889522e-06 Liver_STARNET1
# 4       CEP41 -5.980833 -6.123768e+02 2.220000e-09 8.090718e-06          Liver
# 5      CELSR2  5.931947  3.589004e+00 2.993642e-09 8.090718e-06          Liver
# 6       PSRC1  5.920755  3.487337e-01 3.204668e-09 8.090718e-06          Liver
# 7        CARF  5.486486  6.329079e-01 4.100084e-08 6.101950e-05 Liver_STARNET1
# 8     FAM109A  5.268340  3.642126e-01 1.376630e-07 2.606649e-04          Liver
# 9      PPP1CC  5.008477  2.458786e+00 5.486234e-07 8.310547e-04          Liver
# 10       RAI1  4.621070  2.820820e-01 3.817665e-06 4.545312e-03 Liver_STARNET1
# 11    ZNF286B  4.446075  2.765818e+02 8.745324e-06 9.577189e-03          Liver
# 12      RPL13  4.443484  6.089184e-02 8.851376e-06 9.577189e-03          Liver
# 13       FHL3  4.409401  4.802308e-01 1.036569e-05 1.028449e-02 Liver_STARNET1
# 14     INPP5B  4.373466  1.693308e-01 1.222892e-05 1.039983e-02 Liver_STARNET1
# 15        LPA -4.329781 -1.222189e-01 1.492580e-05 1.110666e-02 Liver_STARNET1
# 16 AC079602.1 -4.259314 -5.514752e-01 2.050556e-05 1.356329e-02 Liver_STARNET1
# 17       LIPA -4.210681 -1.212238e-01 2.546020e-05 1.515646e-02 Liver_STARNET1
# 18       RBM6  4.178397  1.968108e-01 2.935713e-05 1.588755e-02 Liver_STARNET1
# 19      USP39  4.233954  8.626119e-01 2.296182e-05 2.173910e-02          Liver
# 20         F2  4.137191  2.212009e-03 3.515828e-05 2.958765e-02          Liver
# 21   ADAMTSL4  4.013994  4.996552e-01 5.969986e-05 2.961611e-02 Liver_STARNET1
# 22      MAP1S -4.097344 -5.152322e+00 4.179168e-05 3.165302e-02          Liver
# 23    FAM216A -3.968323 -2.445683e-01 7.238030e-05 3.234305e-02 Liver_STARNET1
# 24      RPL13  3.940672  5.477170e-01 8.125367e-05 3.234305e-02 Liver_STARNET1
# 25     TOM1L2  3.925616  4.033045e-01 8.650809e-05 3.234305e-02 Liver_STARNET1
# 26        AXL  3.915427  6.505800e-01 9.024451e-05 3.234305e-02 Liver_STARNET1
# 27       ENSA  3.899840  2.230651e-01 9.625631e-05 3.234305e-02 Liver_STARNET1
# 28     DCAF16  3.895998  3.499100e-01 9.779520e-05 3.234305e-02 Liver_STARNET1
# 29      FCHO1  3.857285  2.417740e-01 1.146534e-04 3.592272e-02 Liver_STARNET1
# 30    PLA2G1B  4.005799  2.900973e-01 6.180815e-05 4.191088e-02          Liver
# 31     ATP5G1 -3.988822 -1.194426e-01 6.640224e-05 4.191088e-02          Liver
#
# $Fatty_liver
#      gene    zscore effect_size       pvalue pvalue_adj         tissue
# 1 C2orf16 -4.458426  -0.6754388 8.256384e-06 0.04850626 Liver_STARNET1
#
# $FC
#             gene     zscore effect_size       pvalue   pvalue_adj
# 1           LIPC -12.760447  -0.3921268 2.726337e-37 1.622988e-33
# 2          PSRC1   6.635514   0.5111294 3.233732e-11 9.625202e-08
# 3          PSRC1  -6.697075  -0.2970437 2.126322e-11 1.654278e-07
# 4           LIPC  -6.221472  -0.0119943 4.925108e-10 1.915867e-06
# 5          SORT1   6.075447   0.3889294 1.236431e-09 2.453492e-06
# 6         CELSR2  -5.925606  -1.7506088 3.111481e-09 8.069106e-06
# 7         CELSR2   5.802983   0.4866653 6.514532e-09 9.695252e-06
# 8  RP11-115J16.1   4.904522   0.1886279 9.365501e-07 1.115057e-03
# 9           PUM2  -4.918214  -3.4752338 8.733733e-07 1.698711e-03
# 10         NLRC5  -4.654694  -3.0163299 3.244629e-06 4.883212e-03
# 11          CETP  -4.623897  -0.2630017 3.765973e-06 4.883212e-03
# 12          DARS  -4.339186  -0.6944768 1.430112e-05 1.253211e-02
# 13          CETP  -4.332595  -0.2830428 1.473623e-05 1.253211e-02
# 14        FCGR2B   4.251649   0.1527716 2.122026e-05 1.579053e-02
# 15         APOC1   4.150765   0.3357680 3.313655e-05 1.977758e-02
# 16         S1PR5  -4.150170  -0.4437390 3.322288e-05 1.977758e-02
# 17        FAM63B   4.080762   0.4738574 4.488827e-05 2.429272e-02
# 18        ZNF350  -4.168875  -3.7995195 3.061073e-05 3.402164e-02
# 19       SLC22A1  -3.975089  -0.1601378 7.035282e-05 3.490086e-02
# 20         MYZAP  -4.052417  -7.4685617 5.069118e-05 4.455211e-02
# 21         GCOM1  -4.048539  -6.0815211 5.153843e-05 4.455211e-02
#            tissue
# 1  Liver_STARNET1
# 2  Liver_STARNET1
# 3           Liver
# 4           Liver
# 5  Liver_STARNET1
# 6           Liver
# 7  Liver_STARNET1
# 8  Liver_STARNET1
# 9           Liver
# 10          Liver
# 11          Liver
# 12 Liver_STARNET1
# 13 Liver_STARNET1
# 14 Liver_STARNET1
# 15 Liver_STARNET1
# 16 Liver_STARNET1
# 17 Liver_STARNET1
# 18          Liver
# 19 Liver_STARNET1
# 20          Liver
# 21          Liver
#
# $T2D
#        gene    zscore effect_size       pvalue   pvalue_adj         tissue
# 1  FRA10AC1  7.626288   4.2376205 2.416095e-14 1.828501e-10          Liver
# 2    TCF7L2  5.720536   1.6662900 1.061888e-08 4.018184e-05          Liver
# 3   CCDC88C  4.901529   0.5761672 9.509353e-07 3.536818e-03 Liver_STARNET1
# 4      SSR1 -4.857587  -0.5632075 1.188247e-06 3.536818e-03 Liver_STARNET1
# 5  HLA-DRB5 -4.387375  -0.1151142 1.147270e-05 1.901769e-02 Liver_STARNET1
# 6   HLA-DRA  4.363863   0.4865237 1.277856e-05 1.901769e-02 Liver_STARNET1
# 7      RFT1 -4.248127  -0.6006725 2.155655e-05 2.416756e-02 Liver_STARNET1
# 8   CYP21A2  4.220664   0.4015084 2.435837e-05 2.416756e-02 Liver_STARNET1
# 9    VPS13C  4.391237   1.8980788 1.127076e-05 2.843236e-02          Liver
# 10   FCHSD2  4.112799   0.3838096 3.908900e-05 3.250585e-02 Liver_STARNET1
# 11    P2RX4  4.087082   0.2077913 4.368331e-05 3.250585e-02 Liver_STARNET1

# %%
source("ks_connectivity.R")
source("correlation_connectivity.R")
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1] "INFO: 500 Instances."
# [1] "INFO: 1000 Instances."
# [1] "INFO: 1500 Instances."
# [1] "INFO: 2000 Instances."
# [1] "INFO: 2500 Instances."
# [1] "INFO: 3000 Instances."
# [1] "INFO: 3500 Instances."
# [1] "INFO: 4000 Instances."
# [1] "INFO: 4500 Instances."
# [1] "INFO: 5000 Instances."
# [1] "INFO: 5500 Instances."
# [1] "INFO: 500 Instances."
# [1] "INFO: 1000 Instances."
# [1] "INFO: 1500 Instances."
# [1] "INFO: 2000 Instances."
# [1] "INFO: 2500 Instances."
# [1] "INFO: 3000 Instances."
# [1] "INFO: 3500 Instances."
# [1] "INFO: 4000 Instances."
# [1] "INFO: 4500 Instances."
# [1] "INFO: 5000 Instances."
# [1] "INFO: 5500 Instances."

# %%
# main function ks score
ks_score <- function(up_signature, down_signature, rank_matrix, compound_name) {
    n = 1
    connectivity_score_vec <- c()
    gene_rank_bing <- rank_matrix
    for (i in 1:ncol(gene_rank_bing)) {
        if (i %% 500 == 0)  { print(paste0("INFO: ", i, " Instances."))}
        pert_vec <- gene_rank_bing[, i]
        up_signature <- up_signature[up_signature %in% pert_vec]   
        down_signature <- down_signature[down_signature %in% pert_vec]
        # get teh rank
        up_v <- match(up_signature, pert_vec)
        down_v <- match(down_signature, pert_vec)
        tmp_s <- .s(up_v, down_v, nrow(gene_rank_bing))
        connectivity_score_vec <- c(connectivity_score_vec, tmp_s)
        
    }
    output_df <- data.frame(compound_name = compound_name, connectivity_score = connectivity_score_vec)
    return(output_df)
    
}

# %%
up_signature_df$entrezgene_id
# Out:
# Error in eval(expr, envir, enclos): object 'up_signature' not found
# Traceback:

# %%
#ks_score_vec <- ks_score(up_signature_df$entrezgene_id, down_signature_df$entrezgene_id, gene_rank_bing, compound_name)

# %%
source("../utilities//gene_id.R")

# %%
id_map(grch38$symbol[4:9], from_ref = "symbol", to_ref = "entrez")
# Out:
# [1] 57147 55732  2268  3075  2519  2729

# %%
library(annotables)
library(dplyr)

# map the id
id_map <- function(id_vec, from_ref, to_ref, annotable = grch38) {
# specific operations
#     if (from_ref == "symbol" & to_ref = "ensembl") {
        
#     } else if (from_ref == "symbol" & to_ref = "ensembl") {
        
#     } else if (from_ref == "symbol" & to_ref = "entrez") {
        
#     } else if (from_ref == "ensembl" & to_ref = "symbol") {
        
#     } else if (from_ref == "ensembl" & to_ref = "entrez") {
        
#     } else if (from_ref == "entrez" & to_ref = "symbol") {
        
#     } else if (from_ref == "extrez" & to_ref = "ensembl") {
        
#     } 

    id_df <- data.frame(raw_id = id_vec)
    colnames(id_df) <- from_ref
    id_df[, from_ref] <- as.character(id_df[, from_ref])
    by_str <- rlang::set_names(quo_name(from_ref), quo_name(from_ref))
    output_df <- id_df %>%
        left_join(annotable, by = by_str) %>%
        distinct_(from_ref, .keep_all = T) %>%
        select_(to_ref)
    return(output_df[, to_ref])                              
    
}

# %%
extract_signature <- function(df) {
    up_idx <- df$zscore > 0
    down_idx <- !up_idx
    up_df <- df[up_idx, ]
    down_df <- df[down_idx, ]
    up_df$entrez <- id_map(up_df$gene, from_ref = "symbol", to_ref = "entrez")
    head(up_df)
    down_df$entrez <- id_map(down_df$gene, from_ref = "symbol", to_ref = "entrez")
    up_df <- up_df[complete.cases(up_df),]
    down_df <- down_df[complete.cases(down_df),]
    output_list <- list(up_df = up_df, down_df = down_df)
    return(output_list)
}

# %%
load("../../signature_list_twas_significant_unique.RData")
df <- signature_list_twas_significant_unique[["FC"]]

# %%
head(df)
# Out:
#   gene          zscore     effect_size pvalue       pvalue_adj   tissue
# 1 LIPC          -12.760447 -0.3921268  2.726337e-37 1.622988e-33 Liver_STARNET1
# 2 PSRC1           6.635514  0.5111294  3.233732e-11 9.625202e-08 Liver_STARNET1
# 3 SORT1           6.075447  0.3889294  1.236431e-09 2.453492e-06 Liver_STARNET1
# 4 CELSR2         -5.925606 -1.7506088  3.111481e-09 8.069106e-06 Liver
# 5 RP11-115J16.1   4.904522  0.1886279  9.365501e-07 1.115057e-03 Liver_STARNET1
# 6 PUM2           -4.918214 -3.4752338  8.733733e-07 1.698711e-03 Liver

# %%
df <- signature_list_twas_significant_unique[["T2D"]]
up_idx <- df$zscore > 0
down_idx <- !up_idx
up_df <- df[up_idx, ]
down_df <- df[down_idx, ]
up_df$entrez <- id_map(up_df$gene, from_ref = "symbol", to_ref = "entrez")
# head(up_df)
# down_df$entrez <- id_map(df$gene, from_ref = "symbol", to_ref = "entrez")
# up_df <- up_df[complete.cases(up_df),]
# down_df <- down_df[complete.cases(down_df),]
# output_list <- list(up_df = up_df, down_df = down_df)

# %%
up_idx
# Out:
#  [1]  TRUE  TRUE  TRUE FALSE  TRUE FALSE  TRUE FALSE  TRUE  TRUE  TRUE

# %%
id_map(df$gene, from_ref = "symbol", to_ref = "entrez")
# Out:
#  [1] 118924   6934 440193   6745   3122   3127   1589  91869  54832   9873
# [11]   5025

# %%
dim(up_df)
# Out:
# [1] 8 6

# %%
unique(id_map(df$gene, from_ref = "symbol", to_ref = "entrez"))
# Out:
#  [1] 118924   6934 440193   6745   3122   3127   1589  91869  54832   9873
# [11]   5025

# %%
down_df
# Out:
#   gene     zscore    effect_size pvalue       pvalue_adj  tissue
# 4 SSR1     -4.857587 -0.5632075  1.188247e-06 0.003536818 Liver_STARNET1
# 6 HLA-DRB5 -4.387375 -0.1151142  1.147270e-05 0.019017694 Liver_STARNET1
# 8 RFT1     -4.248127 -0.6006725  2.155655e-05 0.024167562 Liver_STARNET1

# %%
test_outputlist <- extract_signature(signature_list_twas_significant_unique[["FC"]])

# %%
test_outputlist$up_df
# Out:
#    gene   zscore   effect_size pvalue       pvalue_adj   tissue         entrez
# 2  PSRC1  6.635514 0.5111294   3.233732e-11 9.625202e-08 Liver_STARNET1 84722
# 3  SORT1  6.075447 0.3889294   1.236431e-09 2.453492e-06 Liver_STARNET1  6272
# 10 FCGR2B 4.251649 0.1527716   2.122026e-05 1.579053e-02 Liver_STARNET1  2213
# 11 APOC1  4.150765 0.3357680   3.313655e-05 1.977758e-02 Liver_STARNET1   341

# %%
head(up_signature_df)
# Out:
#   gene_id log2FC    Paired_TTest.x       P_adjusted.x entrezgene_id
# 1 IGFBP2  2.0973080 0.000202895105445194 0.012531722    3485
# 2 CMYA5   1.1595890 0.000351286063494227 0.015516680  202333
# 3 CA14    1.1577054 7.21898619031281e-05 0.008572901   23632
# 4 PPARA   0.9425177 3.8419130807681e-06  0.003508627    5465
# 5 CYP1A2  0.8565970 0.00102640671975578  0.026312026    1544
# 6 CDH23   0.8272671 7.71817164972887e-05 0.008742475   64072
#   ensembl_gene_id nash_1           nash_3           nash_5
# 1 ENSG00000115457 5.52600986116163 5.60623844775563 5.80123838936584
# 2 ENSG00000164309 5.10754545068052 4.52639783134358 5.06078860316949
# 3 ENSG00000118298 3.92695884103164 4.52667728148627 3.31228804446142
# 4 ENSG00000186951 7.09040716835301 7.94337760121244 7.06933213381294
# 5 ENSG00000140505 9.34437946338902 10.8478859370914 11.040719491202
# 6 ENSG00000107736 5.23963135189243 6.22435109678499 5.37161154805623
#   nash_6           ⋯ nonash_11        nonash_13        nonash_14
# 1 4.70580320806404 ⋯ 7.60762971901251 8.21710655454929 6.05645424467979
# 2 4.70682661957452 ⋯ 5.44503180669064 6.02702125102626 4.41449391819054
# 3 3.7611840986548  ⋯ 5.80102330076718 5.28823434108233 3.79072847009234
# 4 7.13154404430531 ⋯ 7.8350016561528  8.12317442534445 7.90121126226443
# 5 10.1625169249533 ⋯ 10.9719082267521 11.5007525062132 11.0083938173085
# 6 5.10531271851035 ⋯ 5.99937447328316 5.50561453595297 5.26636501596013
#   nonash_15        nonash_16        nonash_19        nonash_20
# 1 7.16480158201681 6.88515902007004 5.90900552371629 5.92910472620911
# 2 5.51407806636564 5.69491675835204 5.4191293368975  5.32986323229981
# 3 4.65248678502784 4.98535622245193 4.64702533395229 4.38276310543229
# 4 8.23448266748219 7.70176370316113 7.82085770678669 7.71299357059367
# 5 10.5601374150956 11.1931455636744 10.9987028630248 10.6536886036463
# 6 6.00836272358323 6.1225297657928  5.52887612781896 5.65554151422607
#   logFC             Paired_TTest.y       P_adjusted.y
# 1 1.45374314504699  0.000202895105445194 0.0125317222900259
# 2 0.803765816041033 0.000351286063494227 0.0155166800549362
# 3 0.802460236526014 7.21898619031281e-05 0.0085729014070367
# 4 0.653303496229666 3.8419130807681e-06  0.00350862712101147
# 5 0.593747788836952 0.00102640671975578  0.0263120262966165
# 6 0.573417879203735 7.71817164972887e-05 0.00874247473998747

# %%
merged_up_signature_df <- data.frame(entrez = up_signature_df$entrezgene_id, pvalue_adj = up_signature_df$P_adjusted.x)
merged_down_signature_df <- data.frame(entrez = down_signature_df$entrezgene_id, pvalue_adj = down_signature_df$P_adjusted.x)

# %%
head(merged_up_signature_df)
# Out:
#   entrez pvalue_adj
# 1   3485 0.012531722
# 2 202333 0.015516680
# 3  23632 0.008572901
# 4   5465 0.003508627
# 5   1544 0.026312026
# 6  64072 0.008742475

# %%
merged_up_signature_df <- data.frame(entrez = up_signature_df$entrezgene_id, pvalue_adj = up_signature_df$P_adjusted.x)
merged_down_signature_df <- data.frame(entrez = down_signature_df$entrezgene_id, pvalue_adj = down_signature_df$P_adjusted.x)



merge_signature <- function(merged_up_signature_df, merged_down_signature_df, trait_str_vec) {
    for (trait_str in trait_str_vec) {
        cat(trait_str)
        output_list <- extract_signature(signature_list_twas_significant_unique[[trait_str]])
        tmp_up_df <- output_list$up_df
        tmp_down_df <- output_list$down_df
        tmp_up_df <- tmp_up_df[,c("entrez", "pvalue_adj")]
        tmp_down_df <- tmp_down_df[,c("entrez", "pvalue_adj")]
        merged_up_signature_df <- rbind(merged_up_signature_df, tmp_down_df)
        merged_down_signature_df <- rbind(merged_down_signature_df, tmp_up_df)
    }
    merged_up_signature_df <- merged_up_signature_df %>% arrange(pvalue_adj)
    merged_down_signature_df <- merged_down_signature_df %>% arrange(pvalue_adj)
    output_list <- list(merged_up_signature_df = merged_up_signature_df, merged_down_signature_df = merged_down_signature_df)
    return(output_list)
    
    
}

# %%
signature_list_twas_significant_unique[["T2D"]]
# Out:
#    gene     zscore    effect_size pvalue       pvalue_adj   tissue
# 1  FRA10AC1  7.626288  4.2376205  2.416095e-14 1.828501e-10 Liver
# 2  TCF7L2    5.720536  1.6662900  1.061888e-08 4.018184e-05 Liver
# 3  CCDC88C   4.901529  0.5761672  9.509353e-07 3.536818e-03 Liver_STARNET1
# 4  SSR1     -4.857587 -0.5632075  1.188247e-06 3.536818e-03 Liver_STARNET1
# 5  HLA-DRA   4.363863  0.4865237  1.277856e-05 1.901769e-02 Liver_STARNET1
# 6  HLA-DRB5 -4.387375 -0.1151142  1.147270e-05 1.901769e-02 Liver_STARNET1
# 7  CYP21A2   4.220664  0.4015084  2.435837e-05 2.416756e-02 Liver_STARNET1
# 8  RFT1     -4.248127 -0.6006725  2.155655e-05 2.416756e-02 Liver_STARNET1
# 9  VPS13C    4.391237  1.8980788  1.127076e-05 2.843236e-02 Liver
# 10 FCHSD2    4.112799  0.3838096  3.908900e-05 3.250585e-02 Liver_STARNET1
# 11 P2RX4     4.087082  0.2077913  4.368331e-05 3.250585e-02 Liver_STARNET1

# %%
output_list <- extract_signature(signature_list_twas_significant_unique[["T2D"]])

# %%
trait_vec <- c("Fatty_liver", "FC", "T2D", "CAD")
test_list <- merge_signature(merged_up_signature_df, merged_down_signature_df, trait_vec)
# Out:
# Fatty_liverFCT2DCAD

# %%
trait_vec <- c("Fatty_liver", "FC", "T2D", "CAD", "BMI_GIANT_2015")
test_list_2 <- merge_signature(merged_up_signature_df, merged_down_signature_df, trait_vec)
# Out:
# Fatty_liverFCT2DCADBMI_GIANT_2015

# %%
test_list_2$merged_up_signature_df
# Out:
#     entrez    pvalue_adj
# 1     3990    1.622988e-33
# 2   114900    8.700403e-14
# 3    25970    1.156668e-13
# 4    79172    6.287047e-13
# 5     7284    2.315707e-11
# 6    25989    4.241201e-09
# 7     1952    3.889522e-06
# 8    84722    3.889522e-06
# 9     6272    3.889522e-06
# 10    1952    8.069106e-06
# 11   95681    8.090718e-06
# 12  134359    2.698725e-05
# 13   64386    3.133882e-05
# 14    6631    3.400567e-05
# 15   79759    6.253387e-05
# 16   79003    1.366044e-04
# 17    4215    1.765955e-04
# 18    1768    1.902835e-04
# 19  400506    2.668052e-04
# 20  124446    3.377391e-04
# 21    7444    3.972183e-04
# 22    7770    4.092235e-04
# 23  283899    6.601897e-04
# 24    4864    9.332457e-04
# 25     341    1.128276e-03
# 26   23369    1.698711e-03
# 27   64116    1.854288e-03
# 28   10180    1.898009e-03
# 29    5096    1.986357e-03
# 30   80279    2.087874e-03
# ⋮   ⋮         ⋮
# 182     23469 0.04045972
# 183     51279 0.04080048
# 184     79797 0.04130062
# 185       516 0.04191088
# 186     56521 0.04204428
# 187     80004 0.04237396
# 188       126 0.04247052
# 189      6594 0.04247635
# 190       731 0.04248036
# 191     51161 0.04257246
# 192      1520 0.04257246
# 193      7775 0.04257246
# 194      6821 0.04324642
# 195      3069 0.04343797
# 196    145781 0.04455211
# 197 100820829 0.04455211
# 198     11278 0.04462530
# 199     25932 0.04489549
# 200       319 0.04496929
# 201      2908 0.04605242
# 202      5091 0.04694490
# 203     92312 0.04743314
# 204     79443 0.04759426
# 205      3373 0.04759426
# 206      2639 0.04804893
# 207      3915 0.04836132
# 208     84226 0.04850626
# 209    255239 0.04927350
# 210     55703 0.04955356
# 211     26235 0.04998112

# %%
test_list_2$merged_down_signature_df
# Out:
#     entrez pvalue_adj
# 1     8663 2.315707e-11
# 2    84901 7.651134e-11
# 3   118924 1.828501e-10
# 4     1201 5.099597e-10
# 5     5702 1.156386e-08
# 6    84722 9.625202e-08
# 7    26471 9.780477e-07
# 8    23788 1.733964e-06
# 9     6272 2.453492e-06
# 10      53 5.236302e-06
# 11  339105 7.688658e-06
# 12  146547 7.724881e-06
# 13  400798 1.758819e-05
# 14   79001 2.022984e-05
# 15   54887 2.330616e-05
# 16   84148 2.698725e-05
# 17   57521 2.698725e-05
# 18    5607 3.058330e-05
# 19    8567 3.483986e-05
# 20    6934 4.018184e-05
# 21   83746 5.008243e-05
# 22  390598 5.008243e-05
# 23   79800 6.101950e-05
# 24   50619 1.642884e-04
# 25  144717 2.606649e-04
# 26    6988 2.802190e-04
# 27   11325 3.172468e-04
# 28   80179 3.340810e-04
# 29    9866 3.700774e-04
# 30   27040 3.761220e-04
# ⋮   ⋮      ⋮
# 282   8764 0.04376975
# 283 345757 0.04380575
# 284  10936 0.04385117
# 285  51699 0.04438593
# 286  50640 0.04461309
# 287  80216 0.04493239
# 288   9296 0.04507877
# 289  64343 0.04523461
# 290  80790 0.04528928
# 291   3837 0.04528928
# 292 388324 0.04587358
# 293   9167 0.04605242
# 294   1615 0.04605242
# 295   3043 0.04605356
# 296 729288 0.04622909
# 297   9518 0.04661398
# 298   3875 0.04673677
# 299  50848 0.04731080
# 300   5125 0.04740486
# 301  54103 0.04752137
# 302  51027 0.04759426
# 303 201305 0.04760781
# 304  28982 0.04802680
# 305   5696 0.04804893
# 306   1636 0.04867219
# 307  84131 0.04949753
# 308  80005 0.04950925
# 309  51026 0.04959805
# 310  25934 0.04980941
# 311 120224 0.04994366

# %%
ks_score_vec <- ks_score(test_list$merged_up_signature_df$entrez, test_list$merged_down_signature_df$entrez, gene_rank_bing, compound_name)
# Out:
# [1] "INFO: 500 Instances."
# [1] "INFO: 1000 Instances."
# [1] "INFO: 1500 Instances."
# [1] "INFO: 2000 Instances."
# [1] "INFO: 2500 Instances."
# [1] "INFO: 3000 Instances."
# [1] "INFO: 3500 Instances."
# [1] "INFO: 4000 Instances."
# [1] "INFO: 4500 Instances."
# [1] "INFO: 5000 Instances."
# [1] "INFO: 5500 Instances."

# %%
head(ks_score_vec)
# Out:
#   compound_name    connectivity_score
# 1 rutin             0.1381533
# 2 tyrphostin-AG-82  0.1415256
# 3 AG-957           -0.1578075
# 4 alaproclate       0.1108341
# 5 albendazole      -0.2652008
# 6 alclometasone     0.0000000

# %%
ks_score_vec_2 <- ks_score(test_list_2$merged_up_signature_df$entrez, test_list_2$merged_down_signature_df$entrez, gene_rank_bing, compound_name)
# Out:
# [1] "INFO: 500 Instances."
# [1] "INFO: 1000 Instances."
# [1] "INFO: 1500 Instances."
# [1] "INFO: 2000 Instances."
# [1] "INFO: 2500 Instances."
# [1] "INFO: 3000 Instances."
# [1] "INFO: 3500 Instances."
# [1] "INFO: 4000 Instances."
# [1] "INFO: 4500 Instances."
# [1] "INFO: 5000 Instances."
# [1] "INFO: 5500 Instances."

# %%
head(ks_score_vec_2)
# Out:
#   compound_name    connectivity_score
# 1 rutin             0.0000000
# 2 tyrphostin-AG-82  0.1129620
# 3 AG-957           -0.1502664
# 4 alaproclate       0.0000000
# 5 albendazole       0.0000000
# 6 alclometasone     0.0000000

# %%
check_overlap <- function(gsea_df, nash_drugs) {
    lincs_drugs <- tolower(gsea_df$compound_name)

    midx <- na.omit(match(nash_drugs, lincs_drugs))
    overlapped_drugs <- lincs_drugs[midx]
    sum_overlap <- ifelse(lincs_drugs %in% overlapped_drugs, 1, 0)
    #sum_overlap_top5 <- ifelse(lincs_drugs[(5774-289+1):5774] %in% overlapped_drugs, 1, 0)
    sum_overlap_top5 <- ifelse(lincs_drugs[1:289] %in% overlapped_drugs, 1, 0)
    #sum_overlap_top10 <- ifelse(lincs_drugs[(5774-578+1):5774] %in% overlapped_drugs, 1, 0)
    sum_overlap_top10 <- ifelse(lincs_drugs[1:578] %in% overlapped_drugs, 1, 0)
    sum_overlap_top_all <- ifelse(lincs_drugs %in% overlapped_drugs, 1, 0)
    return(c(sum(sum_overlap_top5), sum(sum_overlap_top10)))
}

# %%
cor_score_vec <- correlation_score_merged(test_list$merged_up_signature_df$entrez, test_list$merged_down_signature_df$entrez, gene_rank_bing, compound_name)
# Out:
# [1] "INFO: 500 Instances."
# [1] "INFO: 1000 Instances."
# [1] "INFO: 1500 Instances."
# [1] "INFO: 2000 Instances."
# [1] "INFO: 2500 Instances."
# [1] "INFO: 3000 Instances."
# [1] "INFO: 3500 Instances."
# [1] "INFO: 4000 Instances."
# [1] "INFO: 4500 Instances."
# [1] "INFO: 5000 Instances."
# [1] "INFO: 5500 Instances."

# %%
cor_score_vec_2 <- correlation_score_merged(test_list_2$merged_up_signature_df$entrez, test_list_2$merged_down_signature_df$entrez, gene_rank_bing, compound_name)
# Out:
# [1] "INFO: 500 Instances."
# [1] "INFO: 1000 Instances."
# [1] "INFO: 1500 Instances."
# [1] "INFO: 2000 Instances."
# [1] "INFO: 2500 Instances."
# [1] "INFO: 3000 Instances."
# [1] "INFO: 3500 Instances."
# [1] "INFO: 4000 Instances."
# [1] "INFO: 4500 Instances."
# [1] "INFO: 5000 Instances."
# [1] "INFO: 5500 Instances."

# %%
drug_str <- "ACARBOSE AMLODIPINE ATORVASTATIN BETAINE CAFFEINE CENICRIVIROC CHOLECALCIFEROL DABIGATRAN DAPAGLIFLOZIN EMRICASAN ERGOCALCIFEROL EXENATIDE EZETIMIBE FENOFIBRATE GLIMEPIRIDE INSULIN GLARGINE INSULIN HUMAN PRADIGASTAT K-877 PX-102 LIRAGLUTIDE QUINIDINE LOSARTAN ROFLUMILAST METFORMIN ROSIGLITAZONE METRELEPTIN ROSUVASTATIN MGL-3196 SELADELPAR MIDAZOLAM SELONSERTIB SEMAGLUTIDE MT-3995 MUROMONAB-CD3 SIMTUZUMAB NAMODENOSON SITAGUPTIN NIVOCASAN SPIRONOLACTONE OBETICHOLIC ACID TELMISARTAN PENTOXIFYLUNE TOFOGLIFLOZIN PERINDOPRIL URSODIOL PIOGLITAZONE"

nash_drugs <- tolower(unlist(stringr::str_split(drug_str, " ")))

# %%
length(nash_drugs)
# Out:
# [1] 50

# %%
check_overlap(ks_score_vec, nash_drugs)
# Out:
# [1] 5 6

# %%
check_overlap(ks_score_vec_2, nash_drugs)
# Out:
# [1] 5 6

# %%
check_overlap(cor_score_vec, nash_drugs)
# Out:
# [1] 5 6

# %%
check_overlap(cor_score_vec_2, nash_drugs)
# Out:
# [1] 5 6

# %%
head(cor_score_vec)
# Out:
#   compound_name    connectivity_score
# 1 rutin             0.025126444
# 2 tyrphostin-AG-82 -0.006243624
# 3 AG-957           -0.101024557
# 4 alaproclate       0.016278843
# 5 albendazole      -0.097867405
# 6 alclometasone     0.080603276

# %%
head(cor_score_vec_2)
# Out:
#   compound_name    connectivity_score
# 1 rutin             0.027139686
# 2 tyrphostin-AG-82  0.033190133
# 3 AG-957           -0.100231361
# 4 alaproclate      -0.009027954
# 5 albendazole      -0.037041661
# 6 alclometasone     0.102211334

# %%
enrichment_phyper <- function(top_5_count, top_10_count, overlapped_count, total_count ) {
    p_5 <- phyper(top_5_count, overlapped_count, total_count-overlapped_count, round(total_count*0.05), lower.tail = F)
    p_10 <- phyper(top_5_count, overlapped_count, total_count-overlapped_count, round(total_count*0.10), lower.tail = F)
    return(c(p_5, p_10))
} 

overlapped_count <- 30
total_count <- 5774

# %%
enrichment_phyper(5, 6, overlapped_count, total_count)
# Out:
# [1] 0.003199728 0.072475657

# %%
trait_vec <- c("Fatty_liver", "FC")
test_list_close <- merge_signature(merged_up_signature_df, merged_down_signature_df, trait_vec)

# %%
getwd()
# Out:
# [1] "/gpfs/ysm/project/zhao/zy92/NASH/dr_multiomics/code"

# %%
# add signatures

ln <- load("../../exp_res_ks_20191002.RData")

ln

ln2 <- load("signature_list_twas_significant.RData")

head(up_signature_df)

signature_list_twas_significant

source("ks_connectivity.R")
source("correlation_connectivity.R")

# main function ks score
ks_score <- function(up_signature, down_signature, rank_matrix, compound_name) {
    n = 1
    connectivity_score_vec <- c()
    gene_rank_bing <- rank_matrix
    for (i in 1:ncol(gene_rank_bing)) {
        if (i %% 500 == 0)  { print(paste0("INFO: ", i, " Instances."))}
        pert_vec <- gene_rank_bing[, i]
        up_signature <- up_signature[up_signature %in% pert_vec]   
        down_signature <- down_signature[down_signature %in% pert_vec]
        # get teh rank
        up_v <- match(up_signature, pert_vec)
        down_v <- match(down_signature, pert_vec)
        tmp_s <- .s(up_v, down_v, nrow(gene_rank_bing))
        connectivity_score_vec <- c(connectivity_score_vec, tmp_s)
        
    }
    output_df <- data.frame(compound_name = compound_name, connectivity_score = connectivity_score_vec)
    return(output_df)
    
}



up_signature_df$entrezgene_id

#ks_score_vec <- ks_score(up_signature_df$entrezgene_id, down_signature_df$entrezgene_id, gene_rank_bing, compound_name)

source("../utilities//gene_id.R")

id_map(grch38$symbol[4:9], from_ref = "symbol", to_ref = "entrez")

library(annotables)
library(dplyr)

# map the id
id_map <- function(id_vec, from_ref, to_ref, annotable = grch38) {
# specific operations
#     if (from_ref == "symbol" & to_ref = "ensembl") {
        
#     } else if (from_ref == "symbol" & to_ref = "ensembl") {
        
#     } else if (from_ref == "symbol" & to_ref = "entrez") {
        
#     } else if (from_ref == "ensembl" & to_ref = "symbol") {
        
#     } else if (from_ref == "ensembl" & to_ref = "entrez") {
        
#     } else if (from_ref == "entrez" & to_ref = "symbol") {
        
#     } else if (from_ref == "extrez" & to_ref = "ensembl") {
        
#     } 

    id_df <- data.frame(raw_id = id_vec)
    colnames(id_df) <- from_ref
    id_df[, from_ref] <- as.character(id_df[, from_ref])
    by_str <- rlang::set_names(quo_name(from_ref), quo_name(from_ref))
    output_df <- id_df %>%
        left_join(annotable, by = by_str) %>%
        distinct_(from_ref, .keep_all = T) %>%
        select_(to_ref)
    return(output_df[, to_ref])                              
    
} 

extract_signature <- function(df) {
    up_idx <- df$zscore > 0
    down_idx <- !up_idx
    up_df <- df[up_idx, ]
    down_df <- df[down_idx, ]
    up_df$entrez <- id_map(up_df$gene, from_ref = "symbol", to_ref = "entrez")
    head(up_df)
    down_df$entrez <- id_map(down_df$gene, from_ref = "symbol", to_ref = "entrez")
    up_df <- up_df[complete.cases(up_df),]
    down_df <- down_df[complete.cases(down_df),]
    output_list <- list(up_df = up_df, down_df = down_df)
    return(output_list)
}

load("../../signature_list_twas_significant_unique.RData")
df <- signature_list_twas_significant_unique[["FC"]]

head(df)

df <- signature_list_twas_significant_unique[["T2D"]]
up_idx <- df$zscore > 0
down_idx <- !up_idx
up_df <- df[up_idx, ]
down_df <- df[down_idx, ]
up_df$entrez <- id_map(up_df$gene, from_ref = "symbol", to_ref = "entrez")
# head(up_df)
# down_df$entrez <- id_map(df$gene, from_ref = "symbol", to_ref = "entrez")
# up_df <- up_df[complete.cases(up_df),]
# down_df <- down_df[complete.cases(down_df),]
# output_list <- list(up_df = up_df, down_df = down_df)


up_idx

id_map(df$gene, from_ref = "symbol", to_ref = "entrez")

dim(up_df)

unique(id_map(df$gene, from_ref = "symbol", to_ref = "entrez"))

down_df

test_outputlist <- extract_signature(signature_list_twas_significant_unique[["FC"]])

test_outputlist$up_df

head(up_signature_df)

merged_up_signature_df <- data.frame(entrez = up_signature_df$entrezgene_id, pvalue_adj = up_signature_df$P_adjusted.x)
merged_down_signature_df <- data.frame(entrez = down_signature_df$entrezgene_id, pvalue_adj = down_signature_df$P_adjusted.x)




head(merged_up_signature_df)

merged_up_signature_df <- data.frame(entrez = up_signature_df$entrezgene_id, pvalue_adj = up_signature_df$P_adjusted.x)
merged_down_signature_df <- data.frame(entrez = down_signature_df$entrezgene_id, pvalue_adj = down_signature_df$P_adjusted.x)



merge_signature <- function(merged_up_signature_df, merged_down_signature_df, trait_str_vec) {
    for (trait_str in trait_str_vec) {
        cat(trait_str)
        output_list <- extract_signature(signature_list_twas_significant_unique[[trait_str]])
        tmp_up_df <- output_list$up_df
        tmp_down_df <- output_list$down_df
        tmp_up_df <- tmp_up_df[,c("entrez", "pvalue_adj")]
        tmp_down_df <- tmp_down_df[,c("entrez", "pvalue_adj")]
        merged_up_signature_df <- rbind(merged_up_signature_df, tmp_down_df)
        merged_down_signature_df <- rbind(merged_down_signature_df, tmp_up_df)
    }
    merged_up_signature_df <- merged_up_signature_df %>% arrange(pvalue_adj)
    merged_down_signature_df <- merged_down_signature_df %>% arrange(pvalue_adj)
    output_list <- list(merged_up_signature_df = merged_up_signature_df, merged_down_signature_df = merged_down_signature_df)
    return(output_list)
    
    
}

signature_list_twas_significant_unique[["T2D"]]

output_list <- extract_signature(signature_list_twas_significant_unique[["T2D"]])

trait_vec <- c("Fatty_liver", "FC", "T2D", "CAD")
test_list <- merge_signature(merged_up_signature_df, merged_down_signature_df, trait_vec)

trait_vec <- c("Fatty_liver", "FC", "T2D", "CAD", "BMI_GIANT_2015")
test_list_2 <- merge_signature(merged_up_signature_df, merged_down_signature_df, trait_vec)

test_list_2$merged_up_signature_df

test_list_2$merged_down_signature_df

ks_score_vec <- ks_score(test_list$merged_up_signature_df$entrez, test_list$merged_down_signature_df$entrez, gene_rank_bing, compound_name)

head(ks_score_vec)

ks_score_vec_2 <- ks_score(test_list_2$merged_up_signature_df$entrez, test_list_2$merged_down_signature_df$entrez, gene_rank_bing, compound_name)

head(ks_score_vec_2)

check_overlap <- function(gsea_df, nash_drugs) {
    lincs_drugs <- tolower(gsea_df$compound_name)

    midx <- na.omit(match(nash_drugs, lincs_drugs))
    overlapped_drugs <- lincs_drugs[midx]
    sum_overlap <- ifelse(lincs_drugs %in% overlapped_drugs, 1, 0)
    #sum_overlap_top5 <- ifelse(lincs_drugs[(5774-289+1):5774] %in% overlapped_drugs, 1, 0)
    sum_overlap_top5 <- ifelse(lincs_drugs[1:289] %in% overlapped_drugs, 1, 0)
    #sum_overlap_top10 <- ifelse(lincs_drugs[(5774-578+1):5774] %in% overlapped_drugs, 1, 0)
    sum_overlap_top10 <- ifelse(lincs_drugs[1:578] %in% overlapped_drugs, 1, 0)
    sum_overlap_top_all <- ifelse(lincs_drugs %in% overlapped_drugs, 1, 0)
    return(c(sum(sum_overlap_top5), sum(sum_overlap_top10)))
}



cor_score_vec <- correlation_score_merged(test_list$merged_up_signature_df$entrez, test_list$merged_down_signature_df$entrez, gene_rank_bing, compound_name)

cor_score_vec_2 <- correlation_score_merged(test_list_2$merged_up_signature_df$entrez, test_list_2$merged_down_signature_df$entrez, gene_rank_bing, compound_name)

drug_str <- "ACARBOSE AMLODIPINE ATORVASTATIN BETAINE CAFFEINE CENICRIVIROC CHOLECALCIFEROL DABIGATRAN DAPAGLIFLOZIN EMRICASAN ERGOCALCIFEROL EXENATIDE EZETIMIBE FENOFIBRATE GLIMEPIRIDE INSULIN GLARGINE INSULIN HUMAN PRADIGASTAT K-877 PX-102 LIRAGLUTIDE QUINIDINE LOSARTAN ROFLUMILAST METFORMIN ROSIGLITAZONE METRELEPTIN ROSUVASTATIN MGL-3196 SELADELPAR MIDAZOLAM SELONSERTIB SEMAGLUTIDE MT-3995 MUROMONAB-CD3 SIMTUZUMAB NAMODENOSON SITAGUPTIN NIVOCASAN SPIRONOLACTONE OBETICHOLIC ACID TELMISARTAN PENTOXIFYLUNE TOFOGLIFLOZIN PERINDOPRIL URSODIOL PIOGLITAZONE"

nash_drugs <- tolower(unlist(stringr::str_split(drug_str, " ")))

length(nash_drugs)



check_overlap(ks_score_vec, nash_drugs)

check_overlap(ks_score_vec_2, nash_drugs)

check_overlap(cor_score_vec, nash_drugs)

check_overlap(cor_score_vec_2, nash_drugs)

head(cor_score_vec)

head(cor_score_vec_2)

enrichment_phyper <- function(top_5_count, top_10_count, overlapped_count, total_count ) {
    p_5 <- phyper(top_5_count, overlapped_count, total_count-overlapped_count, round(total_count*0.05), lower.tail = F)
    p_10 <- phyper(top_5_count, overlapped_count, total_count-overlapped_count, round(total_count*0.10), lower.tail = F)
    return(c(p_5, p_10))
} 

overlapped_count <- 30
total_count <- 5774


enrichment_phyper(5, 6, overlapped_count, total_count)

trait_vec <- c("Fatty_liver", "FC")
test_list_close <- merge_signature(merged_up_signature_df, merged_down_signature_df, trait_vec)
