# %% [markdown]
# ### Module based prediction

# %%
library(data.table)
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:data.table’:
#
#     between, first, last
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
ln <- load("../../module_gene_list.RData")
ln
# Out:
# [1] "gene_list"

# %%
gene_list
# Out:
# $MEroyalblue
#   [1] "HES3"         "SPSB1"        "SLC25A33"     "LOC101927479" "CDC42-IT1"
#   [6] "FAM76A"       "CYR61"        "LRRC8B"       "HAO2-IT1"     "ELF3"
#  [11] "CR2"          "LOC105373211" "LOC101928226" "LOC646471"    "GNG5"
#  [16] "F3"           "HIST2H2BC"    "MCL1"         "TNFSF18"      "PTGS2"
#  [21] "PPP1R15B"     "IL10"         "LAMB3"        "MAP3K8"       "ZNF33A"
#  [26] "FAM35DP"      "VCL"          "C10orf113"    "PKD2L1"       "LOC102724351"
#  [31] "XPNPEP1"      "STX3"         "PLEKHB1"      "LOC100507283" "LOC646383"
#  [36] "RAG2"         "LOC105369455" "LOC100652768" "LOC100288778" "ARNTL2"
#  [41] "CHPT1"        "YBX3"         "TAS2R10"      "MMP19"        "CTDSP2"
#  [46] "DUSP6"        "LINC01089"    "VPS37B"       "LINC00540"    "LOC105370195"
#  [51] "DIAPH3-AS1"   "TDRD3"        "COL4A2"       "RB1-DT"       "FLT1"
#  [56] "ARF6"         "ZC2HC1C"      "FOS"          "JDP2"         "DICER1-AS1"
# ...
